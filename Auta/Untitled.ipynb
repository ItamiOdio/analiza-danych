# %%
import numpy as np
import pandas as pd
from plotnine import *

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN

from sklearn.metrics import silhouette_score

from sklearn.datasets import make_classification

# from sklearn.datasets import make_blobs
# from sklearn.datasets import make_moons
# from sklearn.datasets import make_circle

# %%
n = 1000
X, y = make_classification(n_samples=n,
                           n_features=2,
                           n_redundant=0,
                           n_clusters_per_class=1,
                           random_state=4)

df = pd.DataFrame(X, columns = ['x1', 'x2'])
df['Grupy'] = y
(ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(Grupy)')) + 
 geom_point() +
 theme_minimal() +
 labs(color = 'Grupy'))
# Out:
# <ggplot: (149324241137)>

# %%
# Grupowanie za pomocą k-średnich

km = KMeans(n_clusters=2).fit(df[['x1', 'x2']])

df['klastry_km'] = km.labels_

sylwetka_km = round(silhouette_score(df[['x1', 'x2']], km.labels_), 4)
#sylwetka_km = round(silhouette_score(df[['x1', 'x2']], km.predict(df[['x1', 'x2']])),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_km)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_km}') +
 theme_minimal() +
 labs(color = 'KM')
)
# Out:
# <ggplot: (149324333138)>

# %%
# Gaussian Mixture

gm = GaussianMixture(n_components=2).fit(df[['x1', 'x2']])
# gm.predict_proba(df[['x1', 'x2']])
df['klastry_gm'] = gm.predict(df[['x1', 'x2']])

sylwetka_gm = round(silhouette_score(df[['x1', 'x2']], gm.predict(df[['x1', 'x2']])), 4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_gm)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_gm}') +
 theme_minimal() +
 labs(color = 'GM')
)
# Out:
# <ggplot: (149324783258)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.5, min_samples = 5).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149324934304)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.5, min_samples = 10).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149325079778)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.5, min_samples = 2).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149325132707)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.3, min_samples = 5).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149326630334)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.3, min_samples = 2).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149326668406)>

# %%
# Grupowanie DBSCAN

db = DBSCAN(eps = 0.3, min_samples = 10).fit(df[['x1', 'x2']])   #eps = 5 promie otaczający

df['klastry_db'] = db.labels_
sylwetka_db = round(silhouette_score(df[['x1', 'x2']],  db.labels_),4)

(
ggplot(df,aes(x = 'x1', y = 'x2', color = 'factor(klastry_db)')) + 
 geom_point() +
 annotate('text', x = -2, y = 2.5, label = f'Sylwetka = {sylwetka_db}')+
 theme_minimal() +
 labs(color = 'DB')
)
# Out:
# <ggplot: (149327039169)>

# %%
df = pd.read_csv('auta.csv', index_col = 0)
#df.rename({'Unnamed: 0':'Nazwa'}, axis = 1, inplace=True) #zmiana nazwy kolumny bez jaj powielania
df.shape
df.head()
#df.info()
# Out:
#              Cena  Przebieg  Pojemnosc   KM  diesle
# Audi A3   20900.0  164450.0     1896.0  110    66.9
# Audi A4   25311.4  182000.0     1900.0  130    75.7
# Audi A6   31500.0  185000.0     2496.0  170    82.5
# Audi A8  109000.0  129380.0     4134.0  300    68.1
# Audi Q7  179000.0   72000.0     3000.0  240    89.1

# %%
from sklearn.preprocessing import StandardScaler #do standaryzowania

# %%
z = StandardScaler()

auta = df.copy()
auta[auta.columns] = z.fit_transform(auta[auta.columns])

# %%
auta.head()
# Out:
#              Cena  Przebieg  Pojemnosc        KM    diesle
# Audi A3 -0.198580  0.484563  -0.017676 -0.248784  0.040064
# Audi A4 -0.055174  0.944320  -0.009643  0.202004  0.458097
# Audi A6  0.146007  1.022911   1.187258  1.103579  0.781122
# Audi A8  2.665391 -0.434164   4.476727  4.033697  0.097069
# Audi Q7  4.940965 -1.937346   2.199402  2.681335  1.094646

# %%
# Grupowanie k-średnich
# Docelowo sprawdzić w domu inne metody

km = KMeans(n_clusters = 2).fit(auta)

auta['klastry'] = km.labels_

# %%
# Interpretacja wyników - segmentacja

(ggplot(auta, aes(x = 'klastry', fill = 'factor(klastry)')) +
 geom_bar()+
 theme_minimal()+
 labs(x = 'Klastry', y = 'Liczebność'))
# Out:
# <ggplot: (149327265774)>

# %%
for zm in auta.columns[:-1]:


(ggplot(auta, aes(x = 'klastry', y = 'Cena', fill = 'factor(klastry)')) + 
 geom_boxplot(show_legend = False) + 
 theme_minimal() +
 labs(x = 'Klastry', title = 'Cena'))
# Out:
# <ggplot: (149327448688)>

# %%
for zm in auta.columns[:-1]:
    print((ggplot(auta, aes(x = 'klastry', y = zm, fill = 'factor(klastry)')) + 
 geom_boxplot(show_legend = False) + 
 theme_minimal() +
 labs(x = 'Klastry', title = 'Cena')))

# %%
# Grupa 0 charakteryzuje się wysokim przebiegiem, niską ceną, niską pojemnością, niską liczbą koni.
# Grupa 1 charakteryzuje się niskim przebiegiem, wysoką ceną, wysoką pojemnością, wysoką liczbą koni

# %%
km = KMeans(n_clusters = 3).fit(auta)

auta['klastry'] = km.labels_

(ggplot(auta, aes(x = 'klastry', fill = 'factor(klastry)')) +
 geom_bar()+
 theme_minimal()+
 labs(x = 'Klastry', y = 'Liczebność'))
# Out:
# <ggplot: (149329194247)>
